# %% [markdown]
# <a href="https://colab.research.google.com/github/VijaiyWorld/ML_AI/blob/main/Txt-image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from diffusers import StableDiffusionXLPipeline, DPMSolverSinglestepScheduler

# Load model.
pipe = StableDiffusionXLPipeline.from_pretrained("sd-community/sdxl-flash", torch_dtype=torch.float16).to("cuda")
# Out:
# model_index.json:   0%|          | 0.00/677 [00:00<?, ?B/s]
# Fetching 18 files:   0%|          | 0/18 [00:00<?, ?it/s]
# text_encoder/model.safetensors:   0%|          | 0.00/246M [00:00<?, ?B/s]
# text_encoder_2/model.safetensors:   0%|          | 0.00/1.39G [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/560 [00:00<?, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/588 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/705 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/462 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/856 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# unet/diffusion_pytorch_model.safetensors:   0%|          | 0.00/5.14G [00:00<?, ?B/s]
# ...

# %%
# Ensure sampler uses "trailing" timesteps.
pipe.scheduler = DPMSolverSinglestepScheduler.from_config(pipe.scheduler.config, timestep_spacing="trailing")

# %%
##  timestep spacing : leading , linespae , trailing
##  num inference steps: Denoising step

# %%
Imgval = """4k bmw car at indian village hill station, perfect shot"""

# %%
# Image generation.
pipe(Imgval, num_inference_steps=10, guidance_scale=5).images[0]
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %% [markdown]
# ### Text to Audio

# %%
from transformers import pipeline
import scipy

synthesiser = pipeline("text-to-audio", "facebook/musicgen-small")

# %%
music = synthesiser("morning rington", forward_params={"do_sample": True})

scipy.io.wavfile.write("ringtone.wav", rate=music["sampling_rate"], data=music["audio"])
